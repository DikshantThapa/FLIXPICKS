# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute  import KNNImputer
from sklearn.impute  import SimpleImputer

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
credits_data = pd.read_csv('/Users/dikshantthapa/Desktop/FLIXPICKS/Data/credits.csv',index_col='movie_id')

# %%
movies_data = pd.read_csv('/Users/dikshantthapa/Desktop/FLIXPICKS/Data/movies.csv')

# %%
credits_data.sample(5)
# Out:
#                                               title  \
# movie_id
# 21724                                   Dance Flick
# 80321            Madagascar 3: Europe's Most Wanted
# 82631                               Won't Back Down
# 18487                    The Taking of Pelham 1 2 3
# 13335     Harold & Kumar Escape from Guantanamo Bay
#
#                                                        cast  \
# movie_id
# 21724     [{"cast_id": 2, "character": "Megan", "credit_...
# 80321     [{"cast_id": 2, "character": "Alex (voice)", "...
# 82631     [{"cast_id": 11, "character": "Nona Alberts", ...
# 18487     [{"cast_id": 2, "character": "Walter Garber", ...
# 13335     [{"cast_id": 1, "character": "Harold Lee", "cr...
#
#                                                        crew
# movie_id
# 21724     [{"credit_id": "563e25e5c3a3681b4b028758", "de...
# 80321     [{"credit_id": "52fe47b89251416c910737a5", "de...
# 82631     [{"credit_id": "52fe48619251416c9108a615", "de...
# ...

# %%
credits_data.describe(include='all')
# Out:
#            title  cast  crew
# count       4803  4803  4803
# unique      4800  4761  4776
# top     The Host    []    []
# freq           2    43    28

# %%
movies_data.sample(5)
# Out:
#         budget                                             genres  \
# 827   55000000  [{"id": 18, "name": "Drama"}, {"id": 14, "name...
# 4358         0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 2710         0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 1439  35000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3039   6400000                      [{"id": 18, "name": "Drama"}]
#
#                                     homepage     id  \
# 827                                      NaN    795
# 4358                                     NaN  41469
# 2710  http://www.sonyclassics.com/wildgrass/  37842
# 1439                                     NaN   4515
# 3039      http://myweekwithmarilynmovie.com/  75900
#
#                                                keywords original_language  \
# 827   [{"id": 236, "name": "suicide"}, {"id": 290, "...                en
# 4358        [{"id": 10183, "name": "independent film"}]                en
# ...

# %%
movies_data.corr()
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000 -0.089377    0.505414  0.730823  0.269851
# id           -0.089377  1.000000    0.031202 -0.050425 -0.153536
# popularity    0.505414  0.031202    1.000000  0.644724  0.225502
# revenue       0.730823 -0.050425    0.644724  1.000000  0.251093
# runtime       0.269851 -0.153536    0.225502  0.251093  1.000000
# vote_average  0.093146 -0.270595    0.273952  0.197150  0.375046
# vote_count    0.593180 -0.004128    0.778130  0.781487  0.271944
#
#               vote_average  vote_count
# budget            0.093146    0.593180
# id               -0.270595   -0.004128
# popularity        0.273952    0.778130
# revenue           0.197150    0.781487
# runtime           0.375046    0.271944
# vote_average      1.000000    0.312997
# vote_count        0.312997    1.000000
